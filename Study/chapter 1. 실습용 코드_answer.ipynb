# %% [markdown]
# ### Chapter 1. 데이터 전처리

# %% [markdown]
# 1. 데이터 불러오기
# 2. 데이터 타입 확인
# 3. 데이터 결측치 확인 (데이터 정제 I)
# 4. 데이터 결측치 대체 (데이터 정제 II)
# 5. 데이터 합치기
# 6. 데이터 인덱싱
# 7. 이탈 데이터 전처리 : 일별 데이터 -> 월별 데이터

# %%
import pandas as pd
import numpy as np

import os

# %% [markdown]
# ### 경로 관련

# %%
# 현재 프로세스의 작업 디렉토리 확인
cur_dir = os.getcwd()
print("cur_dir : ", cur_dir, "\n")

# 현재 작업파일의 경로에 있는 리스트 확인 -> 리스트로 반환
dir_list = os.listdir(cur_dir)
print("dir_list : ", dir_list, "\n")

# 특정 경로의 폴더(디렉토리) 생성
os.mkdir(cur_dir + "/dataset")
# Out:
# cur_dir :  /Users/gimda-eun/eodngk
#
# dir_list :  ['.DS_Store', 'dataset', 'chapter 1. 데이터 전처리-샘플 데이터.ipynb', '.ipynb_checkpoints']
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[2], line 10
#       7 print("dir_list : ", dir_list, "\n")
#       9 # 특정 경로의 폴더(디렉토리) 생성
# ---> 10 os.mkdir(cur_dir + "/dataset")
#
# FileExistsError: [Errno 17] File exists: '/Users/gimda-eun/eodngk/dataset'

# %% [markdown]
# ### 특정 경로의 파일 리스트 확인

# %%
data_list = os.listdir(cur_dir + "/dataset/dropout")
print("데이터셋 목록(data_list) : ", data_list)
# Out:
# 데이터셋 목록(data_list) :  ['Dropout.csv', 'df4.csv', 'df1.csv', 'df3.csv', 'df2.csv', 'member.csv']

# %% [markdown]
# ### 데이터 불러오기 type 1 -> dict 형태로 반환

# %%
Dataset = dict()

for data in data_list:
    print(data)
    Dataset[data[0:-4]] = pd.read_csv(cur_dir + f"/dataset/dropout/{data}", index_col = 0)
# Out:
# Dropout.csv
# df4.csv
# df1.csv
# df3.csv
# df2.csv
# member.csv

# %% [markdown]
# ### 데이터 불러오기 type 2 -> dataframe 형태로 각각 반환

# %%
member = pd.read_csv(cur_dir + '/dataset/dropout/member.csv', index_col = 0).reset_index()
df1 = pd.read_csv(cur_dir + '/dataset/dropout/df1.csv', index_col = 0).reset_index()
df2 = pd.read_csv(cur_dir + '/dataset/dropout/df2.csv', index_col = 0).reset_index()
df3 = pd.read_csv(cur_dir + '/dataset/dropout/df3.csv', index_col = 0).reset_index()
df4 = pd.read_csv(cur_dir + '/dataset/dropout/df4.csv', index_col = 0).reset_index()

# %% [markdown]
# ### 데이터 합치기

# %%
dropout = pd.merge(member, df1, how = 'left', left_on = ['ID'], right_on = ['ID'])
dropout = pd.merge(dropout, df2, how = 'left', left_on = ['ID'], right_on = ['ID'])
dropout = pd.merge(dropout, df3, how = 'left', left_on = ['ID'], right_on = ['ID'])
dropout = pd.merge(dropout, df4, how = 'left', left_on = ['ID'], right_on = ['ID'])

# %% [markdown]
# ### 테이블 컬럼 타입 확인

# %%
dropout.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   ID                                              4424 non-null   object
#  1   Nacionality                                     4397 non-null   object
#  2   Gender                                          4397 non-null   object
#  3   Target                                          4416 non-null   object
#  4   Marital status                                  4405 non-null   float64
#  5   Application mode                                4399 non-null   float64
#  6   Application order                               4395 non-null   float64
#  7   Course                                          4403 non-null   float64
#  8   Daytime/evening attendance                      4407 non-null   float64
#  9   Previous qualification                          4403 non-null   float64
#  10  Mother's qualification                          4399 non-null   float64
#  11  Father's qualification                          4397 non-null   float64
#  12  Mother's occupation                             4396 non-null   float64
#  13  Father's occupation                             4399 non-null   float64
#  14  Displaced                                       4397 non-null   float64
#  15  Educational special needs                       4386 non-null   float64
#  16  Debtor                                          4395 non-null   float64
#  17  Tuition fees up to date                         4393 non-null   float64
#  18  Scholarship holder                              4398 non-null   float64
#  19  Age at enrollment                               4398 non-null   float64
#  20  International                                   4395 non-null   float64
#  21  Education                                       111 non-null    float64
#  22  Curricular units 1st sem (credited)             4398 non-null   float64
#  23  Curricular units 1st sem (enrolled)             4387 non-null   float64
#  24  Curricular units 1st sem (evaluations)          4394 non-null   float64
#  25  Curricular units 1st sem (approved)             4396 non-null   float64
#  26  Curricular units 1st sem (grade)                4377 non-null   float64
#  27  Curricular units 1st sem (without evaluations)  4402 non-null   float64
#  28  Curricular units 2nd sem (credited)             4395 non-null   float64
#  29  Curricular units 2nd sem (enrolled)             4406 non-null   float64
#  30  Curricular units 2nd sem (evaluations)          4406 non-null   float64
#  31  Curricular units 2nd sem (approved)             4398 non-null   float64
#  32  Curricular units 2nd sem (grade)                4397 non-null   float64
#  33  Curricular units 2nd sem (without evaluations)  4402 non-null   float64
#  34  Unemployment rate                               4393 non-null   float64
#  35  Inflation rate                                  4389 non-null   float64
#  36  GDP                                             4377 non-null   float64
# dtypes: float64(33), object(4)
# memory usage: 1.3+ MB

# %% [markdown]
# ### 데이터프레임 내의 값 변경

# %%
def change_value(values):
    if values == 'Portuguese':
        return 1
    elif values == 'German':
        return 2
    elif values == 'Spanish':
        return 3
    elif values == 'Italian':
        return 4
    elif values == 'Dutch':
        return 5
    elif values == 'English':
        return 6
    elif values == 'Lithuanian':
        return 7
    elif values == 'Angolan':
        return 8
    elif values == 'Cape Verdean':
        return 9
    elif values == 'Guinean':
        return 10
    elif values == 'Mozambican':
        return 11
    elif values == 'Santomean':
        return 12
    elif values == 'Turkish':
        return 13
    elif values == 'Brazilian':
        return 14
    elif values == 'Romanian':
        return 15
    elif values == 'Moldova':
        return 16
    elif values == 'Mexican':
        return 17
    elif values == 'Ukrainian':
        return 18
    elif values == 'Russian':
        return 19
    elif values == 'Cuban':
        return 20
    elif values == 'Colombian':
        return 21

# %% [markdown]
# ### 데이터 값 변경 version 1 -> 함수/apply 사용

# %%
dropout['Nacionality'] = dropout['Nacionality'].apply(change_value)

# %% [markdown]
# ### 데이터 컬럼 추가

# %% [markdown]
# #### - 빈 컬럼 생성 version 1
# -> DataFrame['추가하고 싶은 컬럼명'] = '컬럼값'

# %%
dropout['Nationality'] = 0

# %% [markdown]
# #### - 빈 컬럼 생성 version 2
# -> insert(loc = 넣고 싶은 새로운 컬럼의 위치, column = 추가하고 싶은 새로운 컬럼명, value = 새로운 컬럼의 값)

# %%
dropout.insert(loc = 2, column = 'Nationality', value = 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dropout.insert(loc = 2, column = 'Nationality', value = 0)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/frame.py:4440, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4434     raise ValueError(
#    4435         "Cannot specify 'allow_duplicates=True' when "
#    4436         "'self.flags.allows_duplicate_labels' is False."
#    4437     )
#    4438 if not allow_duplicates and column in self.columns:
#    4439     # Should this be a different kind of error??
# -> 4440     raise ValueError(f"cannot insert {column}, already exists")
#    4441 if not isinstance(loc, int):
#    4442     raise TypeError("loc must be int")
#
# ValueError: cannot insert Nationality, already exists

# %% [markdown]
# ### 데이터 값 변경 version 2 -> loc 사용

# %%
dropout.loc[dropout['Nacionality'] == 'Portuguese', 'Nationality'] = 1

# %% [markdown]
# ### 컬럼별 중복 제거 개수

# %%
columns_info = dict()
columns = dropout.columns
for col in columns:
    columns_info[col] = len(dropout[col].unique())
    
columns_info
# Out:
# {'ID': 4424,
#  'Nacionality': 22,
#  'Gender': 3,
#  'Target': 4,
#  'Marital status': 7,
#  'Application mode': 19,
#  'Application order': 9,
#  'Course': 18,
#  'Daytime/evening attendance': 3,
#  'Previous qualification': 18,
#  "Mother's qualification": 30,
#  "Father's qualification": 35,
#  "Mother's occupation": 33,
#  "Father's occupation": 47,
#  'Displaced': 3,
#  'Educational special needs': 3,
#  'Debtor': 3,
#  'Tuition fees up to date': 3,
#  'Scholarship holder': 3,
#  'Age at enrollment': 47,
#  'International': 3,
#  'Education': 26,
#  'Curricular units 1st sem (credited)': 22,
#  'Curricular units 1st sem (enrolled)': 24,
#  'Curricular units 1st sem (evaluations)': 36,
#  'Curricular units 1st sem (approved)': 24,
#  'Curricular units 1st sem (grade)': 790,
#  'Curricular units 1st sem (without evaluations)': 12,
#  'Curricular units 2nd sem (credited)': 20,
#  'Curricular units 2nd sem (enrolled)': 23,
#  'Curricular units 2nd sem (evaluations)': 31,
#  'Curricular units 2nd sem (approved)': 21,
#  'Curricular units 2nd sem (grade)': 781,
#  'Curricular units 2nd sem (without evaluations)': 11,
#  'Unemployment rate': 11,
#  'Inflation rate': 10,
#  'GDP': 11,
#  'Nationality': 1}

# %% [markdown]
# ### 데이터 컬럼 탐색

# %%
dropout = dropout.rename(columns = {'Nacionality' : 'Nationality'})
dropout_ation_cnt = dropout.groupby(['Nationality', 'Target']).size().reset_index().pivot(columns='Target', index='Nationality', values=0)
dropout_ation_cnt = dropout_ation_cnt.rename(index={1:'Portuguese', 2:'German', 3:'Spanish', 4:'Italian', 5:'Dutch', 6:'English', 7:'Lithuanian', 8:'Angolan', 9:'Cape Verdean', 10:'Guinean', 11:'Mozambican', 12:'Santomean', 13:'Turkish', 14:'Brazilian', 15:'Romanian', 16:'Moldova', 17:'Mexican', 18:'Ukrainian', 19:'Russian', 20:'Cuban', 21:'Colombian'})
dropout_ation_cnt
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 dropout = dropout.rename(columns = {'Nacionality' : 'Nationality'})
# ----> 2 dropout_ation_cnt = dropout.groupby(['Nationality', 'Target']).size().reset_index().pivot(columns='Target', index='Nationality', values=0)
#       3 dropout_ation_cnt = dropout_ation_cnt.rename(index={1:'Portuguese', 2:'German', 3:'Spanish', 4:'Italian', 5:'Dutch', 6:'English', 7:'Lithuanian', 8:'Angolan', 9:'Cape Verdean', 10:'Guinean', 11:'Mozambican', 12:'Santomean', 13:'Turkish', 14:'Brazilian', 15:'Romanian', 16:'Moldova', 17:'Mexican', 18:'Ukrainian', 19:'Russian', 20:'Cuban', 21:'Colombian'})
#       4 dropout_ation_cnt
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/frame.py:7718, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7713 axis = self._get_axis_number(axis)
#    7715 # https://github.com/python/mypy/issues/7642
#    7716 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7717 # "Union[bool, NoDefault]"; expected "bool"
# -> 7718 return DataFrameGroupBy(
#    7719     obj=self,
#    7720     keys=by,
#    7721     axis=axis,
#    7722     level=level,
#    7723     as_index=as_index,
#    7724     sort=sort,
#    7725     group_keys=group_keys,
#    7726     squeeze=squeeze,  # type: ignore[arg-type]
#    7727     observed=observed,
#    7728     dropna=dropna,
#    7729 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:882, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     879 if grouper is None:
#     880     from pandas.core.groupby.grouper import get_grouper
# --> 882     grouper, exclusions, obj = get_grouper(
#     883         obj,
#     884         keys,
#     885         axis=axis,
#     886         level=level,
#     887         sort=sort,
#     888         observed=observed,
#     889         mutated=self.mutated,
#     890         dropna=self.dropna,
#     891     )
#     893 self.obj = obj
#     894 self.axis = obj._get_axis_number(axis)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/groupby/grouper.py:877, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     873     in_axis, name, gpr = True, gpr, obj[gpr]
#     874     if gpr.ndim != 1:
#     875         # non-unique columns; raise here to get the name in the
#     876         # exception message
# --> 877         raise ValueError(f"Grouper for '{name}' not 1-dimensional")
#     878     exclusions.add(name)
#     879 elif obj._is_level_reference(gpr, axis=axis):
#
# ValueError: Grouper for 'Nationality' not 1-dimensional

# %% [markdown]
# ### 결측치 확인
# - 컬럼별 결측 비율 확인

# %%
null_cnt_df = pd.DataFrame(dropout.isnull().sum()).rename(columns = {0:'null_count'}).reset_index()
null_cnt_df['null_ratio'] = round(null_cnt_df['null_count']/len(dropout) * 100, 2)
null_cnt_df
# Out:
#                                              index  null_count  null_ratio
# 0                                               ID           0        0.00
# 1                                      Nationality          27        0.61
# 2                                           Gender          27        0.61
# 3                                           Target           8        0.18
# 4                                   Marital status          19        0.43
# 5                                 Application mode          25        0.57
# 6                                Application order          29        0.66
# 7                                           Course          21        0.47
# 8                       Daytime/evening attendance          17        0.38
# 9                           Previous qualification          21        0.47
# 10                          Mother's qualification          25        0.57
# 11                          Father's qualification          27        0.61
# 12                             Mother's occupation          28        0.63
# 13                             Father's occupation          25        0.57
# 14                                       Displaced          27        0.61
# 15                       Educational special needs          38        0.86
# 16                                          Debtor          29        0.66
# 17                         Tuition fees up to date          31        0.70
# 18                              Scholarship holder          26        0.59
# 19                               Age at enrollment          26        0.59
# 20                                   International          29        0.66
# 21                                       Education        4313       97.49
# 22             Curricular units 1st sem (credited)          26        0.59
# 23             Curricular units 1st sem (enrolled)          37        0.84
# 24          Curricular units 1st sem (evaluations)          30        0.68
# 25             Curricular units 1st sem (approved)          28        0.63
# 26                Curricular units 1st sem (grade)          47        1.06
# 27  Curricular units 1st sem (without evaluations)          22        0.50
# 28             Curricular units 2nd sem (credited)          29        0.66
# 29             Curricular units 2nd sem (enrolled)          18        0.41
# 30          Curricular units 2nd sem (evaluations)          18        0.41
# 31             Curricular units 2nd sem (approved)          26        0.59
# 32                Curricular units 2nd sem (grade)          27        0.61
# 33  Curricular units 2nd sem (without evaluations)          22        0.50
# 34                               Unemployment rate          31        0.70
# 35                                  Inflation rate          35        0.79
# 36                                             GDP          47        1.06
# 37                                     Nationality           0        0.00

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 결측치 처리
#
# ###  머신러닝 및 데이터 분석에서 상황과 목적에 맞게 처리해야 하는 중요한 프로세스 중 하나
#
#
#
# 1. 결측치 비율이 10% 미만인 경우
# - 삭제 가능
# <p>
#
#
# 2. 결측치 비율이 30% ~ 50%인 경우
# - 삭제 위험
# <p>
#
#
# 3. 결측치 비율이 50% 이상인 경우
# - 데이터 자체에 대한 추가 검증 필요 or 해당 컬럼의 제거 고려
# <p>
#
# ==============================
# ### * 결측치를 처리하는 방법은 다양
#
# 1. 제거
# - 한개 이상의 결측치가 있는 모든 행 제거
#
# 2. 대체
# - 결측치를 특정값(평균, 최소, 최대, 최반값 등등)으로 대체
#
# 3. 보간법
# - 추세를 결측치 이외의 값들을 선형적으로 같은 간격으로 처리 (시계열 데이터에 적합)

# %% [markdown]
# #### Target 변수에 결측치가 있는 행 일괄 제거
# - target 변수에는 결측치가 있어서는 안된다!!!

# %%
# target 변수의 결측치 유무 확인
dropout[dropout['Target'].isnull() == True]
# Out:
#                                         ID  Nationality Gender Target  \
# 250   5fc1c1cb-6ac2-43c9-9a51-7f99922463d4          NaN    NaN    NaN
# 472   7e6e6287-813f-4404-b43e-59d73c2c6de8          NaN    NaN    NaN
# 652   9c66f9e2-edfc-452c-b08f-94d0120f5df3          NaN    NaN    NaN
# 1443  1a235c75-5166-4cf5-b495-50f92479e73f          NaN    NaN    NaN
# 2292  9d74b27a-7e6e-4a1a-a420-6ebab9b5e064          NaN    NaN    NaN
# 3150  1ef15756-3d7b-4919-9375-f84dfeb4668b          NaN    NaN    NaN
# 3413  46e9e673-a0a3-4864-8d8a-8653527f3e07          NaN    NaN    NaN
# 4414  e6d883fa-82e5-488a-a790-efc762757ae3          NaN    NaN    NaN
#
#       Marital status  Application mode  Application order  Course  \
# 250              NaN               NaN                NaN     NaN
# 472              NaN               NaN                NaN     NaN
# 652              NaN               NaN                NaN     NaN
# 1443             NaN               NaN                NaN     NaN
# 2292             NaN               NaN                NaN     NaN
# 3150             NaN               NaN                NaN     NaN
# 3413             NaN               NaN                NaN     NaN
# 4414             NaN               NaN                NaN     NaN
#
#       Daytime/evening attendance  Previous qualification  ...  \
# 250                          NaN                     NaN  ...
# 472                          NaN                     NaN  ...
# 652                          NaN                     NaN  ...
# 1443                         NaN                     NaN  ...
# 2292                         NaN                     NaN  ...
# 3150                         NaN                     NaN  ...
# 3413                         NaN                     NaN  ...
# 4414                         NaN                     NaN  ...
#
#       Curricular units 2nd sem (credited)  \
# 250                                   NaN
# 472                                   NaN
# 652                                   NaN
# 1443                                  NaN
# 2292                                  NaN
# 3150                                  NaN
# 3413                                  NaN
# 4414                                  NaN
#
#       Curricular units 2nd sem (enrolled)  \
# 250                                   NaN
# 472                                   NaN
# 652                                   NaN
# 1443                                  NaN
# 2292                                  NaN
# 3150                                  NaN
# 3413                                  NaN
# 4414                                  NaN
#
#       Curricular units 2nd sem (evaluations)  \
# 250                                      NaN
# 472                                      NaN
# 652                                      NaN
# 1443                                     NaN
# 2292                                     NaN
# 3150                                     NaN
# 3413                                     NaN
# 4414                                     NaN
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 250                                   NaN                               NaN
# 472                                   NaN                               NaN
# 652                                   NaN                               NaN
# 1443                                  NaN                               NaN
# 2292                                  NaN                               NaN
# 3150                                  NaN                               NaN
# 3413                                  NaN                               NaN
# 4414                                  NaN                               NaN
#
#       Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 250                                              NaN                NaN
# 472                                              NaN                NaN
# 652                                              NaN                NaN
# 1443                                             NaN                NaN
# 2292                                             NaN                NaN
# 3150                                             NaN                NaN
# 3413                                             NaN                NaN
# 4414                                             NaN                NaN
#
#       Inflation rate  GDP  Nationality
# 250              NaN  NaN            0
# 472              NaN  NaN            0
# 652              NaN  NaN            0
# 1443             NaN  NaN            0
# 2292             NaN  NaN            0
# 3150             NaN  NaN            0
# 3413             NaN  NaN            0
# 4414             NaN  NaN            0
#
# [8 rows x 38 columns]

# %% [markdown]
# ### 데이터 컬럼 타입 변경

# %%
dropout = dropout.astype({"Marital status" : 'object',
                         "Application mode" : 'object',
                         "Course" : 'object',
                         "Daytime/evening attendance" : 'object',
                         "Previous qualification" : 'object',
                         "Mother's qualification" : 'object',
                         "Father's qualification" : 'object',
                         "Mother's occupation" : 'object',
                         "Father's occupation" : 'object',
                         "Displaced" : 'object',
                         "Educational special needs" : 'object',
                         "Debtor" : 'object',
                         "Tuition fees up to date" : 'object',
                         "Scholarship holder" : 'object',
                         "International" : 'object'})
dropout.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4424 entries, 0 to 4423
# Data columns (total 38 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   ID                                              4424 non-null   object
#  1   Nationality                                     4397 non-null   float64
#  2   Gender                                          4397 non-null   object
#  3   Target                                          4416 non-null   object
#  4   Marital status                                  4405 non-null   object
#  5   Application mode                                4399 non-null   object
#  6   Application order                               4395 non-null   float64
#  7   Course                                          4403 non-null   object
#  8   Daytime/evening attendance                      4407 non-null   object
#  9   Previous qualification                          4403 non-null   object
#  10  Mother's qualification                          4399 non-null   object
#  11  Father's qualification                          4397 non-null   object
#  12  Mother's occupation                             4396 non-null   object
#  13  Father's occupation                             4399 non-null   object
#  14  Displaced                                       4397 non-null   object
#  15  Educational special needs                       4386 non-null   object
#  16  Debtor                                          4395 non-null   object
#  17  Tuition fees up to date                         4393 non-null   object
#  18  Scholarship holder                              4398 non-null   object
#  19  Age at enrollment                               4398 non-null   float64
#  20  International                                   4395 non-null   object
#  21  Education                                       111 non-null    float64
#  22  Curricular units 1st sem (credited)             4398 non-null   float64
#  23  Curricular units 1st sem (enrolled)             4387 non-null   float64
#  24  Curricular units 1st sem (evaluations)          4394 non-null   float64
#  25  Curricular units 1st sem (approved)             4396 non-null   float64
#  26  Curricular units 1st sem (grade)                4377 non-null   float64
#  27  Curricular units 1st sem (without evaluations)  4402 non-null   float64
#  28  Curricular units 2nd sem (credited)             4395 non-null   float64
#  29  Curricular units 2nd sem (enrolled)             4406 non-null   float64
#  30  Curricular units 2nd sem (evaluations)          4406 non-null   float64
#  31  Curricular units 2nd sem (approved)             4398 non-null   float64
#  32  Curricular units 2nd sem (grade)                4397 non-null   float64
#  33  Curricular units 2nd sem (without evaluations)  4402 non-null   float64
#  34  Unemployment rate                               4393 non-null   float64
#  35  Inflation rate                                  4389 non-null   float64
#  36  GDP                                             4377 non-null   float64
#  37  Nationality                                     4424 non-null   int64
# dtypes: float64(19), int64(1), object(18)
# memory usage: 1.3+ MB

# %%
# target 변수에 결측이 있는 row 제거
dropout_remove = dropout[dropout['Target'].isnull() == False]

# %% [markdown]
# ## * 결측치 1차 제거 -> 행 제거
#
# - dropna() 함수 사용
# 1. axis = 0/1 (0 : 행, 1 : 열)
# 2. how = 'any' / 'all' (any : 행/열 중 하나라도 있는 경우 제거, all : 모든 행/열이 결측인 경우 제거)
#
# 3. dropna(thresh = num) : 행의 결측치 개수가 num개 이상인 행 제거
#
# 4. subset = 특정 변수 지정 / 지정하지 않을 경우 : 모든 columne & row에 적용

# %%
dropout_remove = dropout.dropna(axis = 0, thresh = 2)

# %%
dropout_remove = dropout.dropna(axis = 0, how = 'all')
dropout_remove
# Out:
#                                         ID  Nationality  Gender    Target  \
# 0     37c5fefa-df8e-4dcc-aec7-60000f2198e4          1.0    Male   Dropout
# 1     37cf2ef2-2a6f-466a-a8cf-56a753bd8e71          1.0    Male  Graduate
# 2     37ddd4c5-ab63-4b43-8df7-24e98f39f25b          1.0    Male   Dropout
# 3     37fafa03-d77a-4723-89aa-84a8277379c5          1.0  Female  Graduate
# 4     382cc9e8-e885-4bcd-ae4d-a3846c35097b          1.0  Female  Graduate
# ...                                    ...          ...     ...       ...
# 4419  e7592d77-b53d-4496-a276-0fb6afdd7265          1.0    Male  Graduate
# 4420  e76231d5-8450-4424-b344-daac4b02845b         19.0  Female   Dropout
# 4421  e77542f6-e166-46a6-ba62-903e0740631e          1.0  Female   Dropout
# 4422  e7d809db-983c-4db5-b32a-64698a39a5aa          1.0  Female  Graduate
# 4423  e8367558-40d6-4ec6-99a8-e9b2541fdc9b          9.0  Female  Graduate
#
#      Marital status Application mode  Application order Course  \
# 0               1.0              8.0                5.0    2.0
# 1               1.0              6.0                1.0   11.0
# 2               1.0              1.0                5.0    5.0
# 3               1.0              8.0                2.0   15.0
# 4               2.0             12.0                1.0    3.0
# ...             ...              ...                ...    ...
# 4419            1.0              1.0                6.0   15.0
# 4420            1.0              1.0                2.0   15.0
# 4421            1.0              1.0                1.0   12.0
# 4422            1.0              1.0                1.0    9.0
# 4423            1.0              5.0                1.0   15.0
#
#      Daytime/evening attendance Previous qualification  ...  \
# 0                           1.0                    1.0  ...
# 1                           1.0                    1.0  ...
# 2                           1.0                    1.0  ...
# 3                           1.0                    1.0  ...
# 4                           0.0                    1.0  ...
# ...                         ...                    ...  ...
# 4419                        1.0                    1.0  ...
# 4420                        1.0                    1.0  ...
# 4421                        1.0                    1.0  ...
# 4422                        1.0                    1.0  ...
# 4423                        1.0                    1.0  ...
#
#      Curricular units 2nd sem (credited) Curricular units 2nd sem (enrolled)  \
# 0                                    0.0                                 0.0
# 1                                    0.0                                 6.0
# 2                                    0.0                                 6.0
# 3                                    0.0                                 6.0
# 4                                    0.0                                 6.0
# ...                                  ...                                 ...
# 4419                                 0.0                                 6.0
# 4420                                 0.0                                 6.0
# 4421                                 0.0                                 8.0
# 4422                                 0.0                                 5.0
# 4423                                 0.0                                 6.0
#
#      Curricular units 2nd sem (evaluations)  \
# 0                                       0.0
# 1                                       6.0
# 2                                       0.0
# 3                                      10.0
# 4                                       6.0
# ...                                     ...
# 4419                                    8.0
# 4420                                    6.0
# 4421                                    9.0
# 4422                                    6.0
# 4423                                    6.0
#
#      Curricular units 2nd sem (approved) Curricular units 2nd sem (grade)  \
# 0                                    0.0                         0.000000
# 1                                    6.0                        13.666667
# 2                                    0.0                         0.000000
# 3                                    5.0                        12.400000
# 4                                    6.0                        13.000000
# ...                                  ...                              ...
# 4419                                 5.0                        12.666667
# 4420                                 2.0                        11.000000
# 4421                                 1.0                        13.500000
# 4422                                 5.0                        12.000000
# 4423                                 6.0                        13.000000
#
#      Curricular units 2nd sem (without evaluations) Unemployment rate  \
# 0                                               0.0              10.8
# 1                                               0.0              13.9
# 2                                               0.0              10.8
# 3                                               0.0               9.4
# 4                                               0.0              13.9
# ...                                             ...               ...
# 4419                                            0.0              15.5
# 4420                                            0.0              11.1
# 4421                                            0.0              13.9
# 4422                                            0.0               9.4
# 4423                                            0.0              12.7
#
#      Inflation rate   GDP  Nationality
# 0               1.4  1.74            0
# 1              -0.3  0.79            0
# 2               1.4  1.74            0
# 3              -0.8 -3.12            0
# 4              -0.3  0.79            0
# ...             ...   ...          ...
# 4419            2.8 -4.06            0
# 4420            0.6  2.02            0
# 4421           -0.3  0.79            0
# 4422           -0.8 -3.12            0
# 4423            3.7 -1.70            0
#
# [4424 rows x 38 columns]

# %%
# 약 4천개의 행중에서 3000개 이상 결측인 컬럼 제거 -> "Education" 컬럼 제거 됨
dropout_remove = dropout.dropna(axis = 1, thresh = 3000)

# %% [markdown]
# ## * 결측치 특정값 대치(imputation)
#
# 1. 최빈값 : 범주형 변수의 경우 (가장 비율이 높은 범주로 대치 가능)
#
# 2. 중앙값 : 연속형 변수의 경우 중앙값으로 대치 가능
#
# 3. 평균 : 연속형 변수의 경우 평균값으로 대치 가능
#
# 4. 임의 지정 : 사용자가 원하는 수치로 대치 가능

# %% [markdown]
# ### 특정값 대치 version 1 -> fillna() 함수 사용

# %% [markdown]
# #### 타입별 컬럼 리스트 재정의
# - 1. float64 타입에 해당하는 컬럼 리스트 반환
# - 2. Object 타입에 해당하는 컬럼 리스트 반환

# %%
columns_type_list = dropout_remove.columns.to_series().groupby(dropout_remove.dtypes).groups
columns_type_list = {types.name : list(cols) for types, cols in columns_type_list.items()}

# %%
float_list = columns_type_list['float64']
object_list = columns_type_list['object']

# %% [markdown]
# ### * float 타입 컬럼 결측치 대치

# %% [markdown]
# #### 1. float64 타입의 컬럼의 결측치를 모두 각 컬럼의 평균값으로 대치

# %%
for col in float_list:
    means = dropout_remove[col].mean()
    dropout_remove[col] = dropout_remove[col].fillna(means)
# Out:
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/1876490478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(means)
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/1876490478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(means)
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/1876490478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(means)
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/1876490478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(means)
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/1876490478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(means)
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/1876490478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(means)
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/1876490478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(means)
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/1876490478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(means)
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/1876490478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(means)
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/1876490478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(means)
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/1876490478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(means)
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/1876490478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(means)
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/1876490478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(means)
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/1876490478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(means)
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/1876490478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(means)
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/1876490478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(means)
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/1876490478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(means)
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/1876490478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(means)

# %% [markdown]
# #### 2. float64 타입의 컬럼의 결측치를 모두 각 컬럼의 최대값으로 대치
#
# - idxmax() : 최대값을 가지는 인덱스 레이블을 출력
# - max() : 최대값 출력

# %%
for col in float_list:
    max_val = dropout_remove[col].value_counts().idxmax()
    dropout_remove[col] = dropout_remove[col].fillna(max_val)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 for col in float_list:
# ----> 2     max_val = dropout_remove[col].value_counts().idxmax()
#       3     dropout_remove[col] = dropout_remove[col].fillna(max_val)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/frame.py:6576, in DataFrame.value_counts(self, subset, normalize, sort, ascending, dropna)
#    6573 if subset is None:
#    6574     subset = self.columns.tolist()
# -> 6576 counts = self.groupby(subset, dropna=dropna).grouper.size()
#    6578 if sort:
#    6579     counts = counts.sort_values(ascending=ascending)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/frame.py:7718, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7713 axis = self._get_axis_number(axis)
#    7715 # https://github.com/python/mypy/issues/7642
#    7716 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7717 # "Union[bool, NoDefault]"; expected "bool"
# -> 7718 return DataFrameGroupBy(
#    7719     obj=self,
#    7720     keys=by,
#    7721     axis=axis,
#    7722     level=level,
#    7723     as_index=as_index,
#    7724     sort=sort,
#    7725     group_keys=group_keys,
#    7726     squeeze=squeeze,  # type: ignore[arg-type]
#    7727     observed=observed,
#    7728     dropna=dropna,
#    7729 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:882, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     879 if grouper is None:
#     880     from pandas.core.groupby.grouper import get_grouper
# --> 882     grouper, exclusions, obj = get_grouper(
#     883         obj,
#     884         keys,
#     885         axis=axis,
#     886         level=level,
#     887         sort=sort,
#     888         observed=observed,
#     889         mutated=self.mutated,
#     890         dropna=self.dropna,
#     891     )
#     893 self.obj = obj
#     894 self.axis = obj._get_axis_number(axis)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/groupby/grouper.py:877, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     873     in_axis, name, gpr = True, gpr, obj[gpr]
#     874     if gpr.ndim != 1:
#     875         # non-unique columns; raise here to get the name in the
#     876         # exception message
# --> 877         raise ValueError(f"Grouper for '{name}' not 1-dimensional")
#     878     exclusions.add(name)
#     879 elif obj._is_level_reference(gpr, axis=axis):
#
# ValueError: Grouper for 'Nationality' not 1-dimensional

# %% [markdown]
# #### 3. float64 타입의 컬럼의 결측치를 모두 각 컬럼의 최소값으로 대치
# - idxmin() : 최소값을 가지는 인덱스 레이블을 출력
# - min() : 최대값을 출력

# %%
for col in float_list:
    min_val = dropout_remove[col].value_counts().idxmin()
    dropout_remove[col] = dropout_remove[col].fillna(min_val)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 2
#       1 for col in float_list:
# ----> 2     min_val = dropout_remove[col].value_counts().idxmin()
#       3     dropout_remove[col] = dropout_remove[col].fillna(min_val)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/frame.py:6576, in DataFrame.value_counts(self, subset, normalize, sort, ascending, dropna)
#    6573 if subset is None:
#    6574     subset = self.columns.tolist()
# -> 6576 counts = self.groupby(subset, dropna=dropna).grouper.size()
#    6578 if sort:
#    6579     counts = counts.sort_values(ascending=ascending)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/frame.py:7718, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7713 axis = self._get_axis_number(axis)
#    7715 # https://github.com/python/mypy/issues/7642
#    7716 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7717 # "Union[bool, NoDefault]"; expected "bool"
# -> 7718 return DataFrameGroupBy(
#    7719     obj=self,
#    7720     keys=by,
#    7721     axis=axis,
#    7722     level=level,
#    7723     as_index=as_index,
#    7724     sort=sort,
#    7725     group_keys=group_keys,
#    7726     squeeze=squeeze,  # type: ignore[arg-type]
#    7727     observed=observed,
#    7728     dropna=dropna,
#    7729 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:882, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     879 if grouper is None:
#     880     from pandas.core.groupby.grouper import get_grouper
# --> 882     grouper, exclusions, obj = get_grouper(
#     883         obj,
#     884         keys,
#     885         axis=axis,
#     886         level=level,
#     887         sort=sort,
#     888         observed=observed,
#     889         mutated=self.mutated,
#     890         dropna=self.dropna,
#     891     )
#     893 self.obj = obj
#     894 self.axis = obj._get_axis_number(axis)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/groupby/grouper.py:877, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     873     in_axis, name, gpr = True, gpr, obj[gpr]
#     874     if gpr.ndim != 1:
#     875         # non-unique columns; raise here to get the name in the
#     876         # exception message
# --> 877         raise ValueError(f"Grouper for '{name}' not 1-dimensional")
#     878     exclusions.add(name)
#     879 elif obj._is_level_reference(gpr, axis=axis):
#
# ValueError: Grouper for 'Nationality' not 1-dimensional

# %% [markdown]
# #### 4. float64 타입의 컬럼의 결측치를 모두 각 컬럼의 최빈값으로 대치 version 1 -> -> value_counts() + idxmax() 함수 사용

# %%
for col in float_list:
    most_freq_val = dropout_remove[col].value_counts().idxmax()
    dropout_remove[col] = dropout_remove[col].fillna(most_freq_val)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 for col in float_list:
# ----> 2     most_freq_val = dropout_remove[col].value_counts().idxmax()
#       3     dropout_remove[col] = dropout_remove[col].fillna(most_freq_val)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/frame.py:6576, in DataFrame.value_counts(self, subset, normalize, sort, ascending, dropna)
#    6573 if subset is None:
#    6574     subset = self.columns.tolist()
# -> 6576 counts = self.groupby(subset, dropna=dropna).grouper.size()
#    6578 if sort:
#    6579     counts = counts.sort_values(ascending=ascending)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/frame.py:7718, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7713 axis = self._get_axis_number(axis)
#    7715 # https://github.com/python/mypy/issues/7642
#    7716 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7717 # "Union[bool, NoDefault]"; expected "bool"
# -> 7718 return DataFrameGroupBy(
#    7719     obj=self,
#    7720     keys=by,
#    7721     axis=axis,
#    7722     level=level,
#    7723     as_index=as_index,
#    7724     sort=sort,
#    7725     group_keys=group_keys,
#    7726     squeeze=squeeze,  # type: ignore[arg-type]
#    7727     observed=observed,
#    7728     dropna=dropna,
#    7729 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:882, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     879 if grouper is None:
#     880     from pandas.core.groupby.grouper import get_grouper
# --> 882     grouper, exclusions, obj = get_grouper(
#     883         obj,
#     884         keys,
#     885         axis=axis,
#     886         level=level,
#     887         sort=sort,
#     888         observed=observed,
#     889         mutated=self.mutated,
#     890         dropna=self.dropna,
#     891     )
#     893 self.obj = obj
#     894 self.axis = obj._get_axis_number(axis)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/groupby/grouper.py:877, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     873     in_axis, name, gpr = True, gpr, obj[gpr]
#     874     if gpr.ndim != 1:
#     875         # non-unique columns; raise here to get the name in the
#     876         # exception message
# --> 877         raise ValueError(f"Grouper for '{name}' not 1-dimensional")
#     878     exclusions.add(name)
#     879 elif obj._is_level_reference(gpr, axis=axis):
#
# ValueError: Grouper for 'Nationality' not 1-dimensional

# %% [markdown]
# #### 5. float64 타입의 컬럼의 결측치를 모두 각 컬럼의 최빈값으로 대치 version 2 -> mode() 함수 사용

# %%
for col in float_list:
    most_freq_val = dropout_remove[col].mode()[0]
    dropout_remove[col] = dropout_remove[col].fillna(most_freq_val)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "pandas/_libs/index.pyx", line 186, in pandas._libs.index.IndexEngine._get_loc_duplicates
# TypeError: '<' not supported between instances of 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3621, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 136, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 160, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 191, in pandas._libs.index.IndexEngine._get_loc_duplicates
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/3295442472.py", line 2, in <module>
#     most_freq_val = dropout_remove[col].mode()[0]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/frame.py", line 3505, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3623, in get_loc
#     raise KeyError(key) from err
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2057, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1288, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1177, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1049, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/IPython/core/ultratb.py", line 935, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1003, in get_records
#     lines, first = inspect.getsourcelines(etb.tb_frame)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/inspect.py", line 967, in getsourcelines
#     lines, lnum = findsource(object)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/inspect.py", line 798, in findsource
#     raise OSError('could not get source code')
# OSError: could not get source code

# %% [markdown]
# #### 6. float64 타입의 컬럼의 결측치를 모두 각 컬럼의 바로 위 값으로 대치 -> fillna(method = 'ffill')
# - 데이터 특성상 서로 이웃한 데이터끼리 유사성이 높을 수 있다고 간주될 때 사용

# %%
for col in float_list:
    dropout_remove[col] = dropout_remove[col].fillna(method = 'ffill')
# Out:
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/680785113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'ffill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/680785113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'ffill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/680785113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'ffill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/680785113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'ffill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/680785113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'ffill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/680785113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'ffill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/680785113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'ffill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/680785113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'ffill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/680785113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'ffill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/680785113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'ffill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/680785113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'ffill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/680785113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'ffill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/680785113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'ffill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/680785113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'ffill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/680785113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'ffill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/680785113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'ffill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/680785113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'ffill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/680785113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'ffill')

# %% [markdown]
# #### 7. float64 타입의 컬럼의 결측치를 모두 각 컬럼의 바로 아래 값으로 대치 -> fillna(method = 'bfill')
# - 데이터 특성상 서로 이웃한 데이터끼리 유사성이 높을 수 있다고 간주될 때 사용

# %%
for col in float_list:
    dropout_remove[col] = dropout_remove[col].fillna(method = 'bfill')
# Out:
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/3958441077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'bfill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/3958441077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'bfill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/3958441077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'bfill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/3958441077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'bfill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/3958441077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'bfill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/3958441077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'bfill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/3958441077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'bfill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/3958441077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'bfill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/3958441077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'bfill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/3958441077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'bfill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/3958441077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'bfill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/3958441077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'bfill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/3958441077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'bfill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/3958441077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'bfill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/3958441077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'bfill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/3958441077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'bfill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/3958441077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'bfill')
# /var/folders/yv/fm1ff_6j4172zvq3zjps5twr0000gn/T/ipykernel_4819/3958441077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropout_remove[col] = dropout_remove[col].fillna(method = 'bfill')

# %% [markdown]
# #### 8. float 타입의 컬럼의 결측치를 분석가가 원하는 수치로 대치 가능 -> replace() 함수 사용
# - to_replace : 바꾸고 싶은 값
# - value : 바꾸고자 하는 값

# %%
dropout_remove = dropout_remove.replace(to_replace = np.nan, value = 1)

# %% [markdown]
# #### 9. float 타입의 컬럼의 결측치를 성형적으로 같은 간격으로 처리 -> interpolate() 함수 사용 ### 시계열 데이터의 경우 사용 권장

# %%
dropout_remove = dropout_remove.interpolate(method = 'linear', limit_direction = 'forward')

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### * object 타입 컬럼 결측치 대치

# %% [markdown]
# #### 1. object 타입의 컬럼의 결측치를 모두 각 컬럼의 최빈값으로 대치 version 1 -> value_counts() + idxmax() 함수 사용

# %%
for col in object_list:
    most_freq_val = dropout_remove[col].value_counts().idxmax()
    dropout_remove[col] = dropout_remove[col].fillna(most_freq_val)

# %% [markdown]
# #### 2. object 타입의 컬럼의 결측치를 모두 각 컬럼의 최빈값으로 대치 version 2 -> mode() 함수 사용

# %%
for col in object_list:
    most_freq_val = dropout_remove[col].mode()[0]
    dropout_remove[col] = dropout_remove[col].fillna(most_freq_val)

# %% [markdown]
# #### 3. object 타입의 컬럼의 결측치를 모두 각 컬럼의 바로 위 값으로 대치 -> fillna(method = 'ffill')
# - 데이터 특성상 서로 이웃한 데이터끼리 유사성이 높을 수 있다고 간주될 때 사용

# %%
for col in object_list:
    dropout_remove[col] = dropout_remove[col].fillna(method = 'ffill')

# %% [markdown]
# #### 4. object 타입의 컬럼의 결측치를 모두 각 컬럼의 바로 아래 값으로 대치 -> fillna(method = 'bfill')
# - 데이터 특성상 서로 이웃한 데이터끼리 유사성이 높을 수 있다고 간주될 때 사용

# %%
for col in object_list:
    dropout_remove[col] = dropout_remove[col].fillna(method = 'bfill')

# %% [markdown]
# #### 5. object 타입의 컬럼의 결측치를 분석가가 원하는 값으로 대치 가능 -> replace() 함수 사용

# %%
dropout_remove['Nationality'] = dropout_remove['Nationality'].replace(to_replace = np.nan, value = 'Portuguese')

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 데이터 시각화

# %% [markdown]
# ### 시각화 라이브러리
#
# 1. matplotlib
# 2. seaborn
# 3. plotly

# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# '/opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/matplotlib/mpl-data/matplotlibrc'

# %%
import matplotlib.pyplot as plt
import matplotlib
# 그래프 타이틀 한글 출력
# matplotlib.rcParams['font.family'] ='Malgun Gothic'

# 맥북 version 한글 출력
from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# 그래프 사이즈 지정
plt.rcParams['figure.figsize'] = [12, 8]

# %%
Target = dropout_remove['Target'].value_counts()

plt.pie(Target, labels = Target.index, autopct = '%2.1f%%')
plt.title('Target 변수 비율')
plt.show()

# %% [markdown]
# # plotly로 원 그래프 그리기

# %%
import plotly.offline
import plotly.express as px
import plotly.graph_objs as go

# %%
Target = pd.DataFrame(dropout_remove['Target'].value_counts()).reset_index()
fig = px.pie(data_frame = Target, values = 'Target', names = 'index', title = 'Target 변수 비율')
fig.show()
# Out:
# <div>                            <div id="01ca4667-281a-4ccd-b17b-f2f0222a3a03" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01ca4667-281a-4ccd-b17b-f2f0222a3a03")) {                    Plotly.newPlot(                        "01ca4667-281a-4ccd-b17b-f2f0222a3a03",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"index=%{label}\u003cbr\u003eTarget=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Graduate","Dropout","Enrolled",1],"legendgroup":"","name":"","showlegend":true,"values":[2207,1417,792,8],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern": ...
#
# var gd = document.getElementById('01ca4667-281a-4ccd-b17b-f2f

# %%
import seaborn as sns

# %%
sns.countplot(data = dropout_remove, x = 'Gender', hue = 'Target', hue_order = ['Dropout', 'Enrolled', 'Graduate'])
plt.xticks(ticks = [0, 1], labels = ['Female', 'Male'])
plt.ylabel('학생 수')
plt.title('Target별 성비')
plt.show()

# %% [markdown]
# # plotly로 막대그래프 그리기

# %%
pivot_df = dropout_remove.groupby(by = ['Gender', 'Target']).count().reset_index()
pivot_df = pivot_df.loc[:, ['Gender','Target', 'ID']]
pivot_df
# Out:
#    Gender    Target    ID
# 0       1         1     8
# 1       1   Dropout     4
# 2       1  Enrolled     2
# 3       1  Graduate    13
# 4  Female   Dropout   715
# 5  Female  Enrolled   484
# 6  Female  Graduate  1648
# 7    Male   Dropout   698
# 8    Male  Enrolled   306
# 9    Male  Graduate   546

# %%
trace1 = go.Bar(x = pivot_df[pivot_df['Target'] == 'Dropout'].Gender,
                y = pivot_df[pivot_df['Target'] == 'Dropout'].ID,
                name = 'Dropout')

trace2 = go.Bar(x = pivot_df[pivot_df['Target'] == 'Enrolled'].Gender,
                y = pivot_df[pivot_df['Target'] == 'Enrolled'].ID,
                name = 'Enrolled')

trace3 = go.Bar(x = pivot_df[pivot_df['Target'] == 'Graduate'].Gender,
                y = pivot_df[pivot_df['Target'] == 'Graduate'].ID,
                name = 'Graduate')

data = [trace1, trace2, trace3]
layout = go.Layout(title = 'Target별 성비')
fig = go.Figure(data = data, layout = layout)
fig.show()
# Out:
# <div>                            <div id="16f50ea1-9cbd-497f-a518-76b63ad08b73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16f50ea1-9cbd-497f-a518-76b63ad08b73")) {                    Plotly.newPlot(                        "16f50ea1-9cbd-497f-a518-76b63ad08b73",                        [{"name":"Dropout","x":[1,"Female","Male"],"y":[4,715,698],"type":"bar"},{"name":"Enrolled","x":[1,"Female","Male"],"y":[2,484,306],"type":"bar"},{"name":"Graduate","x":[1,"Female","Male"],"y":[13,1648,546],"type":"bar"}],                        {"title":{"text":"Target\ubcc4 \uc131\ube44"},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmo ...
#
# var gd = document.getElementById('16f50ea1-9cbd-497f-a518-76b63ad08b73');
# var x = new MutationObserver(function (mutations, observer) {{
#         var d

# %% [markdown]
# ## 결혼 상태에 따른 Target 변수 비율

# %%
marital_df = pd.crosstab(dropout_remove['Marital status'], dropout_remove['Target'])
marital_df.plot(kind = 'bar', figsize = (16, 4))

plt.xticks(ticks = [0, 1, 2, 3, 4, 5], labels = ['Single', 'Married', 'Widower', 'Divorced', 'Facto Union', 'Legally Seperated'])
plt.xlabel('결혼 상태')
plt.ylabel('학생 수')
plt.title("결혼 상태에 따른 Target 변수 비율")
# Out:
# Text(0.5, 1.0, '결혼 상태에 따른 Target 변수 비율')

# %% [markdown]
# ### 결혼 상태에 따른 Target 변수 비율 구하기 -> plotly 라이브러리 사용

# %%
def change_matrial_val(values):
    if values == 1:
        return 'Single'
    elif values == 2:
        return 'Married'
    elif values == 3:
        return 'Widower'
    elif values == 4:
        return 'Divorced'
    elif values == 5:
        return 'Facto Union'
    elif values == 6:
        return 'Legally Seperated'

# %%
marital_df
# Out:
# Target          1  Dropout  Enrolled  Graduate
# Marital status
# 1.0             8     1180       718      2013
# 2.0             0      179        52       148
# 3.0             0        1         2         1
# 4.0             0       42        16        33
# 5.0             0       11         3        11
# 6.0             0        4         1         1

# %%
marital_df = dropout_remove.groupby(by = ['Marital status', 'Target']).count().reset_index()
marital_df = marital_df.loc[:, ['Marital status','Target', 'ID']]
marital_df['Marital_status'] = marital_df['Marital status'].apply(change_matrial_val)

marital_status = marital_df['Marital_status'].unique().tolist()
print(marital_status)

trace1 = go.Bar(x = marital_df[marital_df['Target'] == 'Dropout'].Marital_status,
               y = marital_df[marital_df['Target'] == 'Dropout'].ID.tolist(), name = 'Single')

trace2 = go.Bar(x = marital_df[marital_df['Target'] == 'Enrolled'].Marital_status,
               y = marital_df[marital_df['Target'] == 'Enrolled'].ID.tolist(), name = 'Married')

trace3 = go.Bar(x = marital_df[marital_df['Target'] == 'Graduate'].Marital_status,
               y = marital_df[marital_df['Target'] == 'Graduate'].ID.tolist(), name = 'Widower')


data = [trace1, trace2, trace3]
layout = go.Layout(barmode = 'group', title = '결혼 상태별 Target 비율')
fig = go.Figure(data = data, layout = layout)
fig.show()
# Out:
# ['Single', 'Married', 'Widower', 'Divorced', 'Facto Union', 'Legally Seperated']
# <div>                            <div id="1c722a57-798e-4148-bff5-a3980d71ed24" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c722a57-798e-4148-bff5-a3980d71ed24")) {                    Plotly.newPlot(                        "1c722a57-798e-4148-bff5-a3980d71ed24",                        [{"name":"Single","x":["Single","Married","Widower","Divorced","Facto Union","Legally Seperated"],"y":[1180,179,1,42,11,4],"type":"bar"},{"name":"Married","x":["Single","Married","Widower","Divorced","Facto Union","Legally Seperated"],"y":[718,52,2,16,3,1],"type":"bar"},{"name":"Widower","x":["Single","Married","Widower","Divorced","Facto Union","Legally Seperated"],"y":[2013,148,1,33,11,1],"type":"bar"}],                        {"barmode":"group","title":{"text":"\uacb0\ud63c \uc0c1\ud0dc\ubcc4 Target \ube44\uc728"},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":" ...

# %% [markdown]
# ## 전공?에 따른 Target 비율

# %%
course_remove = dropout_remove.groupby(by = ['Course', 'Target']).size().reset_index().pivot(columns = 'Target',
                                                                                             index = 'Course',
                                                                                             values = 0)


course_remove = course_remove.rename(index={
    1:'Biofuel Production Technologies',
    2:'Animation and Multimedia Design',
    3:'Social Service (Evening Attendance)',
    4:'Agronomy',5:'Communication Design',
    6:'Veterinary Nursing',
    7:'Informatics Engineering',
    8:'Equiniculture',
    9:'Management',
    10:'Social Service',
    11:'Tourism',
    12:'Nursing',
    13:'Oral Hygiene',
    14:'Advertising and Marketing Management',
    15:'Journalism and Communication',
    16:'Basic Education',
    17:'Management (Evening Attendance)'})

# %%
# 열을 기준으로 각 범주별 총합 계산
course_remove_total = course_remove.sum(axis = 1)

# 총합을 기준으로 오름차순 정렬
course_remove_sorted = course_remove_total.sort_values(ascending = True)

# %%
course_remove.loc[course_remove_sorted.index].plot(kind = 'barh', stacked = True)
plt.title('전공 별 Target 비율')
plt.xlabel('학생 수')
plt.show()

# %% [markdown]
# ### 전공에 따른 Target 비율 -> plotly 라이브러리 사용

# %%
course_df = dropout_remove.groupby(by = ['Course', 'Target']).size().reset_index().rename(columns = {0 : 'ID'})
course_df = course_df.loc[:, ['Course', 'Target', 'ID']]

# %%
name_list = ['Biofuel Production Technologies',
    'Animation and Multimedia Design',
    'Social Service (Evening Attendance)',
    'Agronomy',
    'Communication Design',
    'Veterinary Nursing',
    'Informatics Engineering',
    'Equiniculture',
    'Management',
    'Social Service',
    'Tourism',
    'Nursing',
    'Oral Hygiene',
    'Advertising and Marketing Management',
    'Journalism and Communication',
    'Basic Education',
    'Management (Evening Attendance)']

# %%
def change_course_val(values):
    for idx in range(2, 18):
        if values == 1:
            return 'Biofuel Production Technologies'
        elif values == idx:
            return name_list[idx-1]

# %%
course_df['Course'] = course_df['Course'].apply(change_course_val)

# %%
fig = px.bar(course_df, x = 'Course', y = 'ID', color = 'Target')
fig.show()
# Out:
# <div>                            <div id="b81151f9-1b93-40ea-a7a1-916d7a97ca83" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b81151f9-1b93-40ea-a7a1-916d7a97ca83")) {                    Plotly.newPlot(                        "b81151f9-1b93-40ea-a7a1-916d7a97ca83",                        [{"alignmentgroup":"True","hovertemplate":"Target=1\u003cbr\u003eCourse=%{x}\u003cbr\u003eID=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"v","showlegend":true,"textposition":"auto","x":["Biofuel Production Technologies"],"xaxis":"x","y":[8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Target=Dropout\u003cbr\u003eCourse=%{x}\u003cbr\u003eID=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Dropout","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Dropout","offsetgroup":"Dropout","orientation":"v","showlegend":true,"textposition":"auto","x":["Biofuel Production Technologies","Animation and Multimedia Design","Social Service (Evening Attendance)","Agronomy","Communication Design","Veterinary Nursing","Informatics Engineering","Equiniculture","Management","Social Service","Tourism","Nursing","Oral Hygiene","Advertising and Marketing Management","Journalism and Communication","Basic Education","Management (Evening Attendance)"],"xaxis":"x","y":[8,82,71,85,51,90,92,78,133,65,96,117,33,94,101,85,136],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Target=Enrolled\u003cbr\u003eCourse=%{x}\u003cbr\u003eID=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enrolled","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Enrolled","offsetgroup":"Enrolled","orientation":"v","showlegend":true,"textposition":"auto","x":["Biofuel Production Technologies","Animation and Multimedia Design","Social Service (Evening Attendance)","Agronomy","Communication Design","Veterinary Nursing","Informatics Engineering","Equiniculture","Management","Social Service","Tourism","Nursing","Oral Hygiene","Advertising and Marketing Management","Journalism and Communication","Basic Education","Management (Evening Attendance)"],"xaxis":"x","y":[5,37,21,37,41,75,64,20,107,42,41,99,17,48,34,50,54],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Target=Graduate\u003cbr\u003eCourse=%{x}\u003cbr\u003eID=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Graduate","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Graduate","offsetgroup":"Graduate","orientation":"v","showlegend":true,"textposition":"auto","x":["Biofuel Production Technologies","Animation and Multimedia Design","Social Service (Evening Attendance)","Agronomy","Communication Design","Veterinary Nursing","Informatics Engineering","Equiniculture","Management","Social Service","Tourism","Nursing","Oral Hygiene","Advertising and Marketing Management","Journalism and Communication","Basic Education","Management (Evening Attendance)"],"xaxis":"x","y":[12,96,123,87,133,171,14,41,138,248,115,543,35,125,192,56,78],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111111111111 ...

# %% [markdown]
# ### 국적에 따른 Target 비율
#
# - 포르투칼인이 압도적으로 많아 예측률에 큰 영향은 못 줄 것으로 보임

# %%
nation_df = dropout_remove.groupby(by = ['Nationality', 'Target']).size().reset_index().pivot(columns = 'Target',
                                                                                              index = 'Nationality',
                                                                                              values = 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 nation_df = dropout_remove.groupby(by = ['Nationality', 'Target']).size().reset_index().pivot(columns = 'Target',
#       2                                                                                               index = 'Nationality',
#       3                                                                                               values = 0)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/frame.py:7718, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7713 axis = self._get_axis_number(axis)
#    7715 # https://github.com/python/mypy/issues/7642
#    7716 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7717 # "Union[bool, NoDefault]"; expected "bool"
# -> 7718 return DataFrameGroupBy(
#    7719     obj=self,
#    7720     keys=by,
#    7721     axis=axis,
#    7722     level=level,
#    7723     as_index=as_index,
#    7724     sort=sort,
#    7725     group_keys=group_keys,
#    7726     squeeze=squeeze,  # type: ignore[arg-type]
#    7727     observed=observed,
#    7728     dropna=dropna,
#    7729 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:882, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     879 if grouper is None:
#     880     from pandas.core.groupby.grouper import get_grouper
# --> 882     grouper, exclusions, obj = get_grouper(
#     883         obj,
#     884         keys,
#     885         axis=axis,
#     886         level=level,
#     887         sort=sort,
#     888         observed=observed,
#     889         mutated=self.mutated,
#     890         dropna=self.dropna,
#     891     )
#     893 self.obj = obj
#     894 self.axis = obj._get_axis_number(axis)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/groupby/grouper.py:877, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     873     in_axis, name, gpr = True, gpr, obj[gpr]
#     874     if gpr.ndim != 1:
#     875         # non-unique columns; raise here to get the name in the
#     876         # exception message
# --> 877         raise ValueError(f"Grouper for '{name}' not 1-dimensional")
#     878     exclusions.add(name)
#     879 elif obj._is_level_reference(gpr, axis=axis):
#
# ValueError: Grouper for 'Nationality' not 1-dimensional

# %%
nation_df = nation_df.rename(index={1:'Portuguese',
                                    2:'German',
                                    3:'Spanish',
                                    4:'Italian',
                                    5:'Dutch',
                                    6:'English',
                                    7:'Lithuanian',
                                    8:'Angolan',
                                    9:'Cape Verdean',
                                    10:'Guinean',
                                    11:'Mozambican',
                                    12:'Santomean',
                                    13:'Turkish',
                                    14:'Brazilian',
                                    15:'Romanian',
                                    16:'Moldova',
                                    17:'Mexican',
                                    18:'Ukrainian',
                                    19:'Russian',
                                    20:'Cuban', 
                                    21:'Colombian'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 nation_df = nation_df.rename(index={1:'Portuguese',
#       2                                     2:'German',
#       3                                     3:'Spanish',
#       4                                     4:'Italian',
#       5                                     5:'Dutch',
#       6                                     6:'English',
#       7                                     7:'Lithuanian',
#       8                                     8:'Angolan',
#       9                                     9:'Cape Verdean',
#      10                                     10:'Guinean',
#      11                                     11:'Mozambican',
#      12                                     12:'Santomean',
#      13                                     13:'Turkish',
#      14                                     14:'Brazilian',
#      15                                     15:'Romanian',
#      16                                     16:'Moldova',
#      17                                     17:'Mexican',
#      18                                     18:'Ukrainian',
#      19                                     19:'Russian',
#      20                                     20:'Cuban',
#      21                                     21:'Colombian'})
#
# NameError: name 'nation_df' is not defined

# %%
nation_df_sum = nation_df.sum(axis = 1)
nation_df_sorted = nation_df_sum.sort_values(ascending = True)
nation_df.loc[nation_df_sorted.index].plot(kind = 'barh', stacked = True)

plt.title('국적에 따른 학생 수 (Target 비율)')
plt.xlabel("학생 수")
plt.ylabel('국적')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 nation_df_sum = nation_df.sum(axis = 1)
#       2 nation_df_sorted = nation_df_sum.sort_values(ascending = True)
#       3 nation_df.loc[nation_df_sorted.index].plot(kind = 'barh', stacked = True)
#
# NameError: name 'nation_df' is not defined

# %% [markdown]
# ### 국적에 따른 Target 비율 -> plotly 라이브러리 사용

# %%
nation_df = dropout_remove.groupby(by = ['Nationality', 'Target']).size().reset_index().rename(columns = {0 : 'count'})
nation_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 nation_df = dropout_remove.groupby(by = ['Nationality', 'Target']).size().reset_index().rename(columns = {0 : 'count'})
#       2 nation_df.head()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/frame.py:7718, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7713 axis = self._get_axis_number(axis)
#    7715 # https://github.com/python/mypy/issues/7642
#    7716 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7717 # "Union[bool, NoDefault]"; expected "bool"
# -> 7718 return DataFrameGroupBy(
#    7719     obj=self,
#    7720     keys=by,
#    7721     axis=axis,
#    7722     level=level,
#    7723     as_index=as_index,
#    7724     sort=sort,
#    7725     group_keys=group_keys,
#    7726     squeeze=squeeze,  # type: ignore[arg-type]
#    7727     observed=observed,
#    7728     dropna=dropna,
#    7729 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:882, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     879 if grouper is None:
#     880     from pandas.core.groupby.grouper import get_grouper
# --> 882     grouper, exclusions, obj = get_grouper(
#     883         obj,
#     884         keys,
#     885         axis=axis,
#     886         level=level,
#     887         sort=sort,
#     888         observed=observed,
#     889         mutated=self.mutated,
#     890         dropna=self.dropna,
#     891     )
#     893 self.obj = obj
#     894 self.axis = obj._get_axis_number(axis)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/chunjae/lib/python3.8/site-packages/pandas/core/groupby/grouper.py:877, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     873     in_axis, name, gpr = True, gpr, obj[gpr]
#     874     if gpr.ndim != 1:
#     875         # non-unique columns; raise here to get the name in the
#     876         # exception message
# --> 877         raise ValueError(f"Grouper for '{name}' not 1-dimensional")
#     878     exclusions.add(name)
#     879 elif obj._is_level_reference(gpr, axis=axis):
#
# ValueError: Grouper for 'Nationality' not 1-dimensional

# %%
nation_df = nation_df.sort_values(by = 'count', ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 nation_df = nation_df.sort_values(by = 'count', ascending = False)
#
# NameError: name 'nation_df' is not defined

# %%
fig = px.bar(nation_df, x = 'Nationality', y = 'count', color = 'Target', title = "국적별 학생 수 (Target 비율)")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 fig = px.bar(nation_df, x = 'Nationality', y = 'count', color = 'Target', title = "국적별 학생 수 (Target 비율)")
#       2 fig.show()
#
# NameError: name 'nation_df' is not defined

# %% [markdown]
# ## 연령대 분포도 그리기

# %%
fig = sns.displot(data = dropout_remove, x = 'Age at enrollment', kde = True)
fig.fig.set_size_inches(14, 8)
plt.xlabel('연령대')
plt.ylabel('학생 수')
plt.show()

# %% [markdown]
# ### 연령대 분포도 그리기 -> plotly 라이브러리 사용

# %%
import plotly.figure_factory as ff

# %%
student_cnt = dropout_remove.groupby(by = ['Age at enrollment']).size().reset_index().rename(columns = {0 : 'count'}).astype({'Age at enrollment' : 'object'})

# %%
fig = px.histogram(student_cnt, x = 'Age at enrollment',
                                y = 'count',
                                marginal = 'box', nbins = 50)
# 간격 계산
fig.update_layout(bargap = 0.2)
fig.show()
# Out:
# <div>                            <div id="638321e5-b081-44d9-a3a2-06a64b89984e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("638321e5-b081-44d9-a3a2-06a64b89984e")) {                    Plotly.newPlot(                        "638321e5-b081-44d9-a3a2-06a64b89984e",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Age at enrollment=%{x}\u003cbr\u003esum of count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":50,"offsetgroup":"","orientation":"v","showlegend":false,"x":[17.0,18.0,19.0,20.0,21.0,22.0,23.0,23.2787630741246,24.0,25.0,26.0,27.0,28.0,29.0,30.0,31.0,32.0,33.0,34.0,35.0,36.0,37.0,38.0,39.0,40.0,41.0,42.0,43.0,44.0,45.0,46.0,47.0,48.0,49.0,50.0,51.0,52.0,53.0,54.0,55.0,57.0,58.0,59.0,60.0,61.0,62.0,70.0],"xaxis":"x","y":[5,1030,907,595,318,171,107,26,130,92,93,91,83,66,49,55,61,44,60,49,35,42,29,38,23,31,13,25,21,22,12,18,11,13,16,7,4,7,7,5,2,3,3,2,1,1,1],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","hovertemplate":"Age at enrollment=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":true,"offsetgroup":"","showlegend":false,"x":[17.0,18.0,19.0,20.0,21.0,22.0,23.0,23.2787630741246,24.0,25.0,26.0,27.0,28.0,29.0,30.0,31.0,32.0,33.0,34.0,35.0,36.0,37.0,38.0,39.0,40.0,41.0,42.0,43.0,44.0,45.0,46.0,47.0,48.0,49.0,50.0,51.0,52.0,53.0,54.0,55.0,57.0,58.0,59.0,60.0,61.0,62.0,70.0],"xaxis":"x2","yaxis":"y2","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0 ...

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 히트맵 그리기 -> 변수 선택

# %%
# 인구통계학 데이터

demo_data = dropout_remove[["Marital status", "Nationality", "Displaced", "Gender", "Age at enrollment", "International", "Target"]]

# 사회-경제 데이터
se_data = dropout_remove[["Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation", "Educational special needs", "Debtor", "Tuition fees up to date", "Scholarship holder", "Target"]]

# 미시경제 데이터
me_data = dropout_remove[['Unemployment rate', 'Inflation rate', 'GDP', 'Application mode', 'Application order', 'Course', 'Daytime/evening attendance', 'Previous qualification', 'Target']]

# 학업 데이터
academic_data = dropout_remove[['Curricular units 1st sem (credited)',
       'Curricular units 1st sem (enrolled)',
       'Curricular units 1st sem (evaluations)',
       'Curricular units 1st sem (approved)',
       'Curricular units 1st sem (grade)',
       'Curricular units 1st sem (without evaluations)',
       'Curricular units 2nd sem (credited)',
       'Curricular units 2nd sem (enrolled)',
       'Curricular units 2nd sem (evaluations)',
       'Curricular units 2nd sem (approved)',
       'Curricular units 2nd sem (grade)',
       'Curricular units 2nd sem (without evaluations)', 'Target']]

# %% [markdown]
# ### 인구통계학 데이터 히트맵

# %%
plt.figure(figsize = (7, 5))
sns.heatmap(demo_data.corr(), annot = True, cmap = 'coolwarm', fmt = '.2f')
plt.title('인구 통계학 데이터 - 상관계수')
plt.show()

# %% [markdown]
# ### 사회-경제 데이터 히트맵

# %%
plt.figure(figsize = (7, 5))
sns.heatmap(se_data.corr(), annot = True, fmt = '.2f')
plt.title('사회-경제 데이터 - 상관계수')
plt.show()

# %% [markdown]
# ### 미시경제 데이터 히트맵

# %%
plt.figure(figsize = (7, 5))
sns.heatmap(me_data.corr(), annot = True, cmap = 'YlGnBu', fmt = '.2f')
plt.title('미시경제 데이터 - 상관계수')
plt.show()

# %% [markdown]
# ### 학업 데이터 히트맵

# %%
plt.figure(figsize = (7, 5))
sns.heatmap(academic_data.corr(), annot = True, cmap = 'coolwarm', fmt = '.2f')
plt.title('학업 데이터 - 상관계수')
plt.show()

# %% [markdown]
# # 변수 선택
#
# - 중복성 제거와 과적합 방지를 위해 유사한 상관계수를 가진 변수들 제거

# %%
# 삭제 필요한 컬럼 리스트
need_to_remove_col = ["Curricular units 1st sem (credited)", "Curricular units 1st sem (enrolled)",
       "Curricular units 1st sem (evaluations)", "Curricular units 1st sem (approved)", "Curricular units 1st sem (grade)"]

need_to_remove_col.extend(['Nationality'])

# %%
dropout_remove.drop(need_to_remove_col, axis = 1, inplace = True)

# %%
dropout_remove['Target'].value_counts()
# Out:
# Graduate    2207
# Dropout     1417
# Enrolled     792
# 1              8
# Name: Target, dtype: int64

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 데이터 처리
#
# 1. 컬럼별 타입 확인
# - 문자형, 수치형 확인
#
# 2. 컬럼별 결측치 확인
# - 컬럼별 결측치 비율 확인 후 제거 판별
#
# 3. 결측치 대체 방법 확인
# - 문자형(빈도) / 수치형(평균, 최대/최소값, 최빈값 등)
#
# 4. 결측치 대치 후 최종 확인
# - 결측치 유무 확인
#
# 5. 변수 선택
# - 상관분석 등 기타 분석을 통해 변수 선택 및 제거 진행
#
# 6. 최종 데이터 확인
# - 모델 학습 및 테스트를 위한 최종 데이터 확인
