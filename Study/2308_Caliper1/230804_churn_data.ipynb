# %%
import pandas as pd

import pprint

# %%
la = pd.read_csv('./data/churn/learning_action.csv', index_col=0)
lt = pd.read_csv('./data/churn/learning_time.csv', index_col=0)
sm = pd.read_csv('./data/churn/sample_member.csv', index_col=0)
# Out:
#      proc_ymd                                userid biz_sect_cd_nm  \
# 0    20230518  05723aa6-fcc5-435d-b3d8-1fe3885bf955             초등
# 1    20230502  08463412-6c1f-4fe0-ba8b-30e508fadf10             초등
# 2    20230507  007c1f6e-9004-4f0c-b885-e097d4d20b55             초등
# 3    20230510  12396de0-ef2c-4f0d-b715-6d10d9eeca78             초등
# 4    20230522  1f1151d6-d854-4576-9d47-9b831781cf08             초등
# ..        ...                                   ...            ...
# 952  20230527  c8b0ceb1-bf41-4d65-9b8b-27e8fe1dd65b             초등
# 953  20230531  eeaa37c5-9403-4f1e-a877-88263fdd3fd7             초등
# 954  20230508  dfd6ac7b-f5a2-46a5-ac6c-2e5897475803             초등
# 955  20230503  d294b6dd-ce31-47dd-be4e-fd2093e6c2ea             초등
# 956  20230502  f5f9dd2b-3a81-47e4-a687-ddb212b7a995             초등
#
#     mbr_sex_cd_nm mbr_step_cd_nm user_grade user_grade_nm mbr_status_cd_nm  \
# 0               남          유료학습생       G015          초5학년               사용
# ...

# %%
display(la)
display(lt)
display(sm)
# Out:
#        proc_ymd                                userid  media_action_cnt  \
# 0      20230518  05723aa6-fcc5-435d-b3d8-1fe3885bf955              18.0
# 1      20230512  05723aa6-fcc5-435d-b3d8-1fe3885bf955               4.0
# 2      20230516  05723aa6-fcc5-435d-b3d8-1fe3885bf955               NaN
# 3      20230505  05723aa6-fcc5-435d-b3d8-1fe3885bf955               4.0
# 4      20230510  05723aa6-fcc5-435d-b3d8-1fe3885bf955              10.0
# ...         ...                                   ...               ...
# 84229  20230522  f5f9dd2b-3a81-47e4-a687-ddb212b7a995               5.0
# 84230  20230522  f5f9dd2b-3a81-47e4-a687-ddb212b7a995              18.0
# 84231  20230502  f5f9dd2b-3a81-47e4-a687-ddb212b7a995               NaN
# 84232  20230518  f5f9dd2b-3a81-47e4-a687-ddb212b7a995              15.0
# 84233  20230502  f5f9dd2b-3a81-47e4-a687-ddb212b7a995               9.0
#
#        non_video_viewed_cnt  video_start_cnt  video_restart_cnt  \
# ...

# %% [markdown]
# # Data
